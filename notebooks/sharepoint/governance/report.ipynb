# %% [markdown]
# # SharePoint Tenant Governance Report
#
# Interactive tenant health dashboard covering site inventory, sharing exposure,
# stale content, external users, hub topology, and archived sites.
#
# > **Requires:** tenant admin credentials with `SharePoint Administrator` role.
# > **Docs:** [SPO Tenant Admin REST API](https://learn.microsoft.com/en-us/sharepoint/dev/apis/sharepoint-rest-api-index)
#
# ---

# %% [markdown]
# ## 0 · Setup

# %%
from __future__ import annotations

import warnings
from datetime import datetime, timezone

import pandas as pd
from IPython.display import display
from office365.sharepoint.client_context import ClientContext
from office365.sharepoint.tenant.administration.sharing_capabilities import SharingCapabilities
from office365.sharepoint.tenant.administration.tenant import Tenant
from office365.sharepoint.tenant.management.office365_tenant import Office365Tenant
from tests import test_admin_site_url, test_client_id, test_client_secret

warnings.filterwarnings("ignore")
pd.set_option("display.max_colwidth", 80)
pd.set_option("display.max_rows", 200)

# ── Auth ───────────────────────────────────────────────────────────────────────
ctx = ClientContext(test_admin_site_url).with_client_credentials(
    test_client_id, test_client_secret
)
tenant = Tenant(ctx)
o365 = Office365Tenant(ctx)

SHARING_LABELS = {
    SharingCapabilities.Disabled:                        "Disabled",
    SharingCapabilities.ExternalUserSharingOnly:         "Authenticated external only",
    SharingCapabilities.ExternalUserAndGuestSharing:     "Anyone (links + guests)",
    SharingCapabilities.ExistingExternalUserSharingOnly: "Existing guests only",
}

STALE_DAYS = 180   # sites with no content change beyond this are flagged

print(f"Connected to: {test_admin_site_url}")
print(f"Report generated: {datetime.now(timezone.utc).strftime('%Y-%m-%d %H:%M UTC')}")
# Out:
# Connected to: https://mediadev8-admin.sharepoint.com
# Report generated: 2026-05-23 13:23 UTC

# %% [markdown]
# ---
# ## 1 · Site Inventory
#
# Full list of SharePoint site collections with owner, sharing policy, lock state,
# hub membership, and last content change. This is the foundation for every other
# section of the report.

# %%
sites = (
    tenant
    .get_site_properties_from_sharepoint_by_filters(include_detail=True)
    .execute_query()
)

now = datetime.now(timezone.utc)

rows = []
for s in sites:
    last_modified = s.last_content_modified_date
    # last_content_modified_date returns datetime.min when not set
    if last_modified and last_modified.year > 2000:
        lm_aware = last_modified.replace(tzinfo=timezone.utc) if last_modified.tzinfo is None else last_modified
        days_since = (now - lm_aware).days
    else:
        days_since = None

    rows.append({
        "Title":        s.title or "(no title)",
        "URL":          s.url,
        "Owner":        s.owner_login_name,
        "Sharing":      SHARING_LABELS.get(s.sharing_capability, str(s.sharing_capability)),
        "Lock":         s.lock_state or "Unlock",
        "Hub":          "✓" if s.is_hub_site else "",
        "Days since change": days_since,
        "Archived":     "✓" if s.archived_by else "",
    })

df_sites = pd.DataFrame(rows)
print(f"Total sites: {len(df_sites)}")
display(df_sites)
# Out:
# Total sites: 1492
#                                        Title  \
# 0                                 (no title)
# 1                                       Apps
# 2     Group_697268d10f58463e83324479d13a034b
# 3                              GroupX15DDOGV
# 4     Group_e08b20cc3e8d4615b464a8f1cd8dfe69
# ...                                      ...
# 1487  Group_43afcd361db341109b5096006aade6dd
# 1488  Group_749dfe3d7fff4686b711dfd74273c063
# 1489  Group_89edb28b518448f6a7b9c88978bee297
# 1490  Group_ed42c54139284e968ac3fe208bc10f70
# 1491  Group_ea132ebc284443b1b2e73f6f7cbfde34
#
#                                                                                 URL  \
# 0                                           https://mediadev8.sharepoint.com/search
# 1                                 https://mediadev8.sharepoint.com/sites/appcatalog
# 2     https://mediadev8.sharepoint.com/sites/Group_697268d10f58463e83324479d13a034b
# 3                              https://mediadev8.sharepoint.com/sites/GroupX15DDOGV
# 4     https://mediadev8.sharepoint.com/sites/Group_e08b20cc3e8d4615b464a8f1cd8dfe69
# ...                                                                             ...
# 1487  https://mediadev8.sharepoint.com/sites/Group_43afcd361db341109b5096006aade6dd
# 1488  https://mediadev8.sharepoint.com/sites/Group_749dfe3d7fff4686b711dfd74273c063
# 1489  https://mediadev8.sharepoint.com/sites/Group_89edb28b518448f6a7b9c88978bee297
# 1490  https://mediadev8.sharepoint.com/sites/Group_ed42c54139284e968ac3fe208bc10f70
# 1491  https://mediadev8.sharepoint.com/sites/Group_ea132ebc284443b1b2e73f6f7cbfde34
#
#      Owner                      Sharing    Lock Hub  Days since change  \
# 0     None                     Disabled  Unlock                      4
# 1     None                     Disabled  Unlock                      0
# 2     None  Authenticated external only  Unlock                      4
# 3     None  Authenticated external only  Unlock                      4
# 4     None  Authenticated external only  Unlock                      4
# ...    ...                          ...     ...  ..                ...
# 1487  None  Authenticated external only  Unlock                     18
# 1488  None  Authenticated external only  Unlock                     18
# 1489  None  Authenticated external only  Unlock                     18
# 1490  None  Authenticated external only  Unlock                     18
# 1491  None  Authenticated external only  Unlock                     18
#
#      Archived
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 1487
# 1488
# 1489
# 1490
# 1491
#
# [1492 rows x 8 columns]

# %% [markdown]
# ---
# ## 2 · Sharing Exposure
#
# Sites grouped by sharing capability. `Anyone (links + guests)` is the highest
# risk category — anyone with the link can access content without authentication.

# %%
sharing_summary = (
    df_sites
    .groupby("Sharing")
    .size()
    .reset_index(name="Count")
    .sort_values("Count", ascending=False)
)
display(sharing_summary)

# High-risk sites: Anyone link sharing enabled
high_risk = df_sites[df_sites["Sharing"] == "Anyone (links + guests)"]
print(f"\n⚠️  High-risk sites (anyone link sharing): {len(high_risk)}")
if len(high_risk):
    display(high_risk[["Title", "URL", "Owner", "Lock"]])
# Out:
#                        Sharing  Count
# 1  Authenticated external only   1434
# 2                     Disabled     56
# 0      Anyone (links + guests)      2
# ⚠️  High-risk sites (anyone link sharing): 2
#              Title                                          URL Owner    Lock
# 662   SiteUU0QJSAA            https://mediadev8.sharepoint.com/  None  Unlock
# 1342          team  https://mediadev8.sharepoint.com/sites/team  None  Unlock

# %% [markdown]
# ---
# ## 3 · Stale Sites (>{STALE_DAYS} days since last content change)
#
# Candidates for archiving, lifecycle review, or deletion.
# `Days since change` is based on `LastContentModifiedDate` from the admin API.
# Sites with no recorded modification date are listed separately.

# %%
df_with_date = df_sites[df_sites["Days since change"].notna()].copy()
df_no_date   = df_sites[df_sites["Days since change"].isna()].copy()

stale = (
    df_with_date[df_with_date["Days since change"] > STALE_DAYS]
    .sort_values("Days since change", ascending=False)
)

print(f"Stale sites (>{STALE_DAYS} days): {len(stale)}")
print(f"Sites with no modification date:  {len(df_no_date)}")

display(stale[["Title", "URL", "Owner", "Days since change", "Sharing", "Archived"]])
# Out:
# Stale sites (>180 days): 0
# Sites with no modification date:  0
# Empty DataFrame
# Columns: [Title, URL, Owner, Days since change, Sharing, Archived]
# Index: []

# %% [markdown]
# ---
# ## 4 · Locked Sites
#
# Sites in `ReadOnly` or `NoAccess` lock state. These are blocked from normal
# user operations — usually due to storage quota breach, compliance hold, or
# manual administrative action.

# %%
locked = df_sites[df_sites["Lock"].isin(["ReadOnly", "NoAccess"])].copy()
print(f"Locked sites: {len(locked)}")
if len(locked):
    display(locked[["Title", "URL", "Owner", "Lock", "Sharing"]])
else:
    print("✅ No locked sites found.")
# Out:
# Locked sites: 0
# ✅ No locked sites found.

# %% [markdown]
# ---
# ## 5 · Archived Sites
#
# Sites that have been placed in archive state. Archived sites are read-only and
# count against storage but not against active site limits.

# %%
archived = df_sites[df_sites["Archived"] == "✓"].copy()
print(f"Archived sites: {len(archived)}")
if len(archived):
    display(archived[["Title", "URL", "Owner", "Days since change"]])
else:
    print("No archived sites.")
# Out:
# Archived sites: 0
# No archived sites.

# %% [markdown]
# ---
# ## 6 · Hub Site Topology
#
# Hub sites and their registered details. Hub sites are the backbone of
# SharePoint information architecture — orphaned or mis-configured hubs
# create navigation and search fragmentation.

# %%
hub_sites = tenant.get_hub_sites().execute_query()

hub_rows = []
for h in hub_sites:
    hub_rows.append({
        "Title":    h.title,
        "Site URL": h.site_url,
        "Hub ID":   str(h.id),
    })

df_hubs = pd.DataFrame(hub_rows) if hub_rows else pd.DataFrame(columns=["Title", "Site URL", "Hub ID"])
print(f"Hub sites: {len(df_hubs)}")
display(df_hubs)

# Cross-reference: which inventory sites are hub members?
hub_members = df_sites[df_sites["Hub"] == "✓"][["Title", "URL", "Owner"]]
print(f"\nSites flagged as hub sites in inventory: {len(hub_members)}")
display(hub_members)
# Out:
# Hub sites: 16
#                                    Title  \
# 0                            CommSite123
# 1                            CommSite123
# 2                            CommSite123
# 3                            CommSite123
# 4                            CommSite123
# 5                            CommSite123
# 6                            CommSite123
# 7                            CommSite123
# 8                            CommSite123
# 9                            CommSite123
# 10                           CommSite123
# 11                           CommSite123
# 12  site0cda73fede8049baa25bd9595aa02f8c
# 13  sitead047e43446242afaa6a7d8b150e676f
# 14  sitec9e82cdd4192485a889660857abcb302
# 15  sitee8577d133aa3425697d7a729c3d0359d
#
#                                                                        Site URL  \
# 0       https://mediadev8.sharepoint.com/sites/7a7cc4d1742b46b6ac5ae1972377fc62
# 1       https://mediadev8.sharepoint.com/sites/af12422d6ce14685b074621c7a82a389
# 2       https://mediadev8.sharepoint.com/sites/e7f41ca730f149e783dd8a0be3cc5a48
# 3       https://mediadev8.sharepoint.com/sites/8ec92e3e84be48b1af7b954b2625013c
# 4       https://mediadev8.sharepoint.com/sites/55c47804ccc34f5aad40a76f275706c8
# 5       https://mediadev8.sharepoint.com/sites/95db463d65c8434ea6ddae545fb12f0d
# 6       https://mediadev8.sharepoint.com/sites/91e50592fc6d45b598390b3c52514e51
# 7       https://mediadev8.sharepoint.com/sites/91eba707dedf40a4b7e2f52366cc6aa4
# 8       https://mediadev8.sharepoint.com/sites/b1dda5855672406f8921311387845c67
# 9       https://mediadev8.sharepoint.com/sites/c36cb683c5554db9ac341c84ee2bda24
# 10      https://mediadev8.sharepoint.com/sites/3c6dbc7da28c4391aef67bd1d1a90cd4
# 11      https://mediadev8.sharepoint.com/sites/7c378bfc258d4938a7645b1cfb232f48
# 12  https://mediadev8.sharepoint.com/sites/site0cda73fede8049baa25bd9595aa02f8c
# 13  https://mediadev8.sharepoint.com/sites/sitead047e43446242afaa6a7d8b150e676f
# 14  https://mediadev8.sharepoint.com/sites/sitec9e82cdd4192485a889660857abcb302
# 15  https://mediadev8.sharepoint.com/sites/sitee8577d133aa3425697d7a729c3d0359d
#
#                                   Hub ID
# 0   532085f9-903e-413f-9b86-cbe4751485eb
# 1   d62cbd6b-3245-4786-a6f3-5cbec7882cb3
# 2   7f5fdbe9-a304-4dd4-b475-ba6e32c1198a
# 3   00c21bf8-a69c-455d-81c2-472a60a35e16
# 4   6f8ba1dd-98fa-4ef5-97dd-5664cd95ac1e
# 5   8078829b-f15b-4fc4-b153-c3b5af5784e6
# 6   44a7a573-106a-40b9-ac8c-44b39be8d314
# 7   0f78c5eb-c151-4bfa-a159-3f90edeedc68
# 8   96d9e045-5168-4777-ba65-6f7d1f71f8be
# 9   35fdcacf-ea5d-4bd5-8a49-e6fb4a64b475
# 10  c54986a2-0745-4060-a4a3-77ea8f544b53
# 11  ae5953dc-b764-4a29-83d2-89923252e9f5
# 12  373a5289-1682-4e3d-aab7-dc983be6f811
# 13  65e92122-55ab-4d45-a0d1-d5cf3c07563c
# 14  a42da590-bf3d-4dec-a121-a6d5f57cb7a2
# 15  d7f037e6-220a-44b5-88aa-3ecfb7995de4
# Sites flagged as hub sites in inventory: 0
# Empty DataFrame
# Columns: [Title, URL, Owner]
# Index: []

# %% [markdown]
# ---
# ## 7 · External Users
#
# Guest and external accounts with access to your tenant. Returned in pages of
# up to 50; this cell iterates all pages. High external user count combined with
# `Anyone` sharing is the most common over-exposure pattern.

# %%
all_external = []
position = 0
page_size = 50

while True:
    result = o365.get_external_users(position=position, page_size=page_size).execute_query()
    users = result.external_user_collection
    if not users:
        break
    for u in users:
        props = u.properties
        all_external.append({
            "Display name":    props.get("DisplayName"),
            "Email":           props.get("Email") or props.get("LoginName"),
            "Accepted":        props.get("AcceptedAs"),
            "When created":    props.get("WhenCreated"),
            "Invited by":      props.get("InvitedBy"),
        })
    if len(users) < page_size:
        break
    position += page_size

df_external = pd.DataFrame(all_external)
print(f"Total external users: {len(df_external)}")
if len(df_external):
    display(df_external.sort_values("Email"))
else:
    print("✅ No external users found.")
# Out:
# Total external users: 0
# ✅ No external users found.

# %% [markdown]
# ---
# ## 8 · Governance Summary
#
# Single-glance health scorecard. Use this as the executive summary or as a
# baseline to track improvement over time.

# %%
total         = len(df_sites)
high_risk_n   = len(df_sites[df_sites["Sharing"] == "Anyone (links + guests)"])
stale_n       = len(stale)
locked_n      = len(locked)
archived_n    = len(archived)
hub_n         = len(df_hubs)
external_n    = len(df_external)

summary = pd.DataFrame([
    {"Metric": "Total site collections",             "Value": total},
    {"Metric": "High-risk sharing (anyone links)",   "Value": high_risk_n},
    {"Metric": f"Stale sites (>{STALE_DAYS} days)",  "Value": stale_n},
    {"Metric": "Locked sites",                       "Value": locked_n},
    {"Metric": "Archived sites",                     "Value": archived_n},
    {"Metric": "Hub sites",                          "Value": hub_n},
    {"Metric": "External / guest users",             "Value": external_n},
])

display(summary.style.hide(axis="index"))

risk_pct = round(high_risk_n / total * 100, 1) if total else 0
stale_pct = round(stale_n / total * 100, 1) if total else 0
print(f"\nRisk exposure:  {risk_pct}% of sites allow anyone-link sharing")
print(f"Stale content:  {stale_pct}% of sites have not changed in >{STALE_DAYS} days")
# Out:
# <style type="text/css">
# </style>
# <table id="T_20f3c">
#   <thead>
#     <tr>
#       <th id="T_20f3c_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_20f3c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20f3c_row0_col0" class="data row0 col0" >Total site collections</td>
#       <td id="T_20f3c_row0_col1" class="data row0 col1" >1492</td>
#     </tr>
#     <tr>
#       <td id="T_20f3c_row1_col0" class="data row1 col0" >High-risk sharing (anyone links)</td>
#       <td id="T_20f3c_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_20f3c_row2_col0" class="data row2 col0" >Stale sites (>180 days)</td>
#       <td id="T_20f3c_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_20f3c_row3_col0" class="data row3 col0" >Locked sites</td>
#       <td id="T_20f3c_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_20f3c_row4_col0" class="data row4 col0" >Archived sites</td>
#       <td id="T_20f3c_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_20f3c_row5_col0" class="data row5 col0" >Hub sites</td>
#       <td id="T_20f3c_row5_col1" class="data row5 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_20f3c_row6_col0" class="data row6 col0" >External / guest users</td>
#       <td id="T_20f3c_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
# Risk exposure:  0.1% of sites allow anyone-link sharing
# Stale content:  0.0% of sites have not changed in >180 days
